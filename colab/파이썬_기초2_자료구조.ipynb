# %% [markdown]
# <a href="https://colab.research.google.com/github/hongrolee/Python/blob/main/colab/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%882_%EC%9E%90%EB%A3%8C%EA%B5%AC%EC%A1%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **파이썬 자료구조 (Data Structure)**

# %% [markdown]
# ## **1. 리스트(List)**
# * 여러가지 자료를 저장할 수 있는 데이터 구조체
# * 요소(value) : 리스트 내 데이터를 의미
# * 인덱스(index) : 리스트 내 데이터의 주소
# <br>![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) 일차원 리스트

# %% [markdown]
# ### (2) 다차원 리스트
#
# *   [[ ],[ ],[ ]]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (3) 슬라이싱 (데이터 접근)
#
# *   **array[index]** : 특정 인덱스의 값 접근
# *   **array[start:stop:step]** : 특정 범위의 값 접근
# *   **array[-stop]** : 뒤에서 부터 접근
# *   **array[index][index]** : 다차원 리스트 접근
# *   **list.index(value)** : value를 통한 index 가져오기
# *   **zip(list1, list2)** : 2개의 리스트를 받아서 항목 2개를 묶어서 제공
# <br>for q, a in zip(list1, list2)
# *   숫자 0부터 시작
# *   범위를 벗어난 인덱스 접근시 error 발생

# %% [markdown]
# ### (4) 리스트 연산자
#
# *   \+ : 리스트 합치기
# *   \* : 리스트 반복하기
# *   in : 특정 값 포함 여부 확인, True 또는 False 출력
# *   not in : 특정 값 불포함 여부 확인, True 또는 False 출력

# %% [markdown]
# ### (5) 리스트 관련 함수
#
#    <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<추가 관련>
# *   **list.append(value)** : 마지막에 요소 추가
# *   **list.insert(index, value)** : 인덱스에 요소 추가
# *   **list.extend(list2)** : 리스트 뒤에 확장 또는 추가, + 연산자와 동일
# <br><br> <삭제 관련>
# *   **del list[index]** : 리스트 내 하나의 요소 제거
# *   **del list[index:index]** : 특정 범위의 요소들 제거
# *   **del list[:index]** : 처음부터 인덱스 바로 직전까지 제거
# *   **list.pop(index)** : 리스트 내 하나의 요소 제거, del과 유사
# *   **list.remove(value)** : 특정 값을 지정하여 제거, 단 처음 하나만 제거
# *   **list.clear()** : 요소들 모두 제거
# <br><br> <재배치>
# *   **list.sort()** : 정렬
# *   **sorted(list)** : 정렬된 새로운 리스트 반환
# *   **round(list)** : 반올림, 하나의 값만 가능, numpy는 가능
# <br><br><검색 및 계산>
# *   **len(list)** : 리스트의 길이 측정
# *   **min(list)** : 최소값 가져오기
# *   **max(list)** : 최대값 가져오기
# *   **cmp(list1, list2)** : 첫번째 리스트가 두번째보다 크면 1일 반환
# *   **sum(list)** : 모든 요소의 합계
# *   **ord(list)** : 유니코드 문자의 코드값 반환
# *   **all(list)** : 모든 요소가 참이면 참 반환
# *   **any(list)** : 한 요소라도 참이면 참 반환
# *   **enumerate(list)** : 인덱스와 요소를 함께 반환
# *   **itertools.accumulate(list)** : 누적 결과를 반환
# *   **random.choice(list)** : 리스트에서 랜덤 선택

# %% [markdown]
# ### (6) 리스트와 함수
#
# *   call by value
# *   call by reference

# %% [markdown]
# ### (7) 리스트 함축
#
# *   리스트의 요소를 생성하는 문장을 리스트 안에 넣어 집합 생성
# *   파이썬만이 가진 독특한 문법
# *   사용법> [수식 for (변수 in 리스트) if 조건]
# <br>예> squares = [x*x for x in range(10) if x%2 == 0]

# %% [markdown]
# ### <실습>

# %% [markdown]
# ####<실습1> 성적처리 프로그램
# * 특정 과목의 점수를 입력받아 합계, 평균, 최고득점자, 최저 득점자 찾기

# %% [markdown]
# ####<실습2> 리스트 내에서 n번째 큰 수 찾기

# %% [markdown]
# ####<실습3> 평가점수 도출 프로그램(대회, 용역 등)
# * 평가위원의 최대점수 및 최소점수를 제외한 점수 도출

# %% [markdown]
# #### <실습4> 로또번호 자동 생성기

# %% [markdown]
# ## **2. 튜플(Tuple)**
#
# *   리스트와 유사하나 수정이 불가한 자료구조
# *   리스트 : [ , , ],   **튜플 : ( , , )**
# *   <주의> 요소가 1개인 튜플은 요소의 끝에 반드시 쉼표(,) 추가
#
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<튜플의 장점>
# 1.   데이터 변경 금지(locking) 효과
# 2.   반복문에서 리스트보다 빠름
# 3.   딕셔너리의 키가 될 수 있음

# %% [markdown]
# ### (1) 리스트와 튜플 변환
#
# *   리스트와 튜플은 **서로 변환이 가능**
# *   tpl = tuple(list), 반대로 list = list(tuple)

# %% [markdown]
# ### (2) Packing/Unpacking
#
# *   Packing : tuple = (value, value, value)
# *   Unpacking : (a, b, c) = tuple

# %% [markdown]
# ### (3) 변경 불가 예외사항
#
# *   += 연산자를 통한 튜플 연장은 가능
# *   튜플 내 리스트가 있을 경우 리스트는 수정 가능
# *   튜플을 리스트에 추가하는 것도 가능 (list += tuple)

# %% [markdown]
# ## **3. 세트(Set)**
#
# *   고유한 값들을 저장하는 자료구조
# *   순서대로 저장되지 않으며, 인덱스를 통한 접근 불가
# *   리스트 : [ , , ], 튜플 : ( , , ), **세트 : { , , }**

# %% [markdown]
# ### (1) 리스트와 세트 변환
#
# *   리스트와 세트는 **서로 변환이 가능**
# *   s = set(list), 반대로 list = list(set)
# *   <주의> 하나의 요소를 가진 문자열은 문자로 나뉨
#     <br>s = set("hello")

# %% [markdown]
# ### (2) 추가/삭제
#
# *   세트는 튜플과는 달리 추가/삭제가 가능
# *   인덱스가 없기 때문에 추가/삭제 시 **add(), remove() or discard()** 사용
# *   **set.clear(), set.update(list)** 가능

# %% [markdown]
# ### (3) 세트 함축
#
# *   리스트로부터 세트의 요소를 생성하는 문장을 세트 안에 넣어 집합 생성
# *   사용법> **{수식 for (변수 in 리스트) if 조건}**
# <br>예> squares = {x*x for x in range(10) if x%2 == 0}

# %% [markdown]
# ### (4) 세트 연산자
#
# *  **A \< B 또는 A.isubset(B)** : 부분집합 판단
# *  **A == B 또는 !=** &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;: 동일 또는 다른 집합인지 판단
# *  **A  | B 또는 A.union(B)**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;: 합집합 도출
# *  **A  & B 또는 A.intersection(B)** : 교집합 도출
# *  **A  - B 또는 A.difference(B)** : 교집합 도출

# %% [markdown]
# ### <실습>
#
#
# *   문장으로부터 중복 또는 중복되지 않은 단어 모으기

# %% [markdown]
# ## **4. 딕셔너리(Dictionary)**
#
# *   key를 기반으로 value 저장
# *   value에는 list가 올 수 있음
# *   { key:value, key:value, ..., key:value }
# *   key는 변수로 지정 가능
# <br>![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) 탐색
# *   **딕셔너리명[key] **: 키를 통한 데이터 접근
# *   **딕셔너리명.get(value1, value2)** : value1을 통해 키를 검색하고 없으면 value2 리턴
# *   **딕셔너리명.keys()** : 모든 keys 반환
# *   **딕셔너리명.values()** : 모든 values 반환
# *   **딕셔너리명.items()** : 모든 keys와 values 반환

# %% [markdown]
# ### (2) 수정 및 추가
# *   **딕셔너리명[key] = value** : 키가 존재하면 수정, 존재하지 않으면 추가
# *   **딕셔너리1.update(딕셔너리2)** : 여러 개를 한꺼번에 수정

# %% [markdown]
# ### (3) 삭제
# *   **del(딕셔너리명[key])**
# *   **딕셔너리명.pop(key)**

# %% [markdown]
# ### (4) 딕셔너리 함축
#
# *   리스트로부터 딕셔너리의 요소를 생성하는 문장을 딕셔너리 안에 넣어 집합 생성
# *   파이썬만이 가진 독특한 문법
# *   사용법> {key : value(수식) for 변수 in 리스트 if 조건}
# <br>예> dic = {x : x*x for x in list if x%2 == 0}

# %% [markdown]
# ### <실습>
#
# *   주소록 만들기
# *   학생들 평균성적 처리

# %% [markdown]
# ## **5. 스택(stack)**
# * 스택(stack)은 삽입과 삭제 연산이 후입선출(LIFO:Last-in First-out)로 이루어진 자료구조
# * 스택은 깊이 우선 탐색(DFS: Depth First Search)에 효과적으로 사용되므로 반드시 알아야 할 구조
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) 생성
# * stack = []

# %% [markdown]
# ### (2) 위치확인
# * top : 삽입과 삭제가 일어나는 위치를 의미
# * s[-1] : top 위치의 현재 데이터를 확인

# %% [markdown]
# ### (3) 삽입
# * s.append(data) : top 위치에 새로운 데이터를 삽입하는 연산

# %% [markdown]
# ### (4) 삭제
# * s.pop(): top 위치에 현재 있는 데이터를 삭제하고 확인하는 연산

# %% [markdown]
# ## **6. 큐(queue)**
# * 큐(queue)는 삽입과 삭제 연산이 선입선출(FIFO : First-in First-out)로 이루어진 자료구조
# * 너비 우선 탐색(BFS : Breadth First Search)에서 자주 사용
# ![image.png](data:image/png;base64,...)
